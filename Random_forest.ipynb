# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_row' ,1000)
pd.set_option('display.max_columns', 1000)

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df.shape
# Out:
# (7043, 21)

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null float64
# ...

# %% [markdown]
# # Telecom churn dataset

# %%
df2 = df

# %%
df2.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Since Customer ID is useless let's remove it

# %%
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
df = df.drop('customerID', axis =1)

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
nums = df.select_dtypes(include = [np.number])

# %%
objs = df.select_dtypes(include = [np.object])

# %%
df.shape[1] == nums.shape[1]+objs.shape[1]
# Out:
# True

# %%
nums.columns
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges'], dtype='object')

# %%
objs.columns
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='object')

# %%
flags = []
categoricals = []
for i in objs.columns:
    if (objs[i].value_counts().shape[0] == 2):
        print(i,"=====" ,objs[i].value_counts().shape[0])
        print(objs[i].value_counts().index)
        print("\n")
        flags.append(i)
    else:
        categoricals.append(i)
# Out:
# gender ===== 2
# Index(['Male', 'Female'], dtype='object')
#
#
# Partner ===== 2
# Index(['No', 'Yes'], dtype='object')
#
#
# Dependents ===== 2
# Index(['No', 'Yes'], dtype='object')
#
#
# PhoneService ===== 2
# Index(['Yes', 'No'], dtype='object')
#
#
# PaperlessBilling ===== 2
# Index(['Yes', 'No'], dtype='object')
#
#
# Churn ===== 2
# Index(['No', 'Yes'], dtype='object')

# %%
for i in flags:
    df = pd.get_dummies(df, columns = [i], drop_first= True)

# %%
categoricals
# Out:
# ['MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaymentMethod']

# %%
for i in categoricals:
    df = pd.get_dummies(df, columns= [i], drop_first= True)

# %%
df
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 0                 0       1           29.85         29.85            0
# 1                 0      34           56.95       1889.50            1
# 2                 0       2           53.85        108.15            1
# 3                 0      45           42.30       1840.75            1
# 4                 0       2           70.70        151.65            0
# ...             ...     ...             ...           ...          ...
# 7038              0      24           84.80       1990.50            1
# 7039              0      72          103.20       7362.90            0
# 7040              0      11           29.60        346.45            0
# 7041              1       4           74.40        306.60            1
# 7042              0      66          105.65       6844.50            1
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  PaperlessBilling_Yes  \
# ...

# %% [markdown]
# # dataset is ML ready

# %%
from sklearn.model_selection import train_test_split

# %%
df['TotalCharges'] = df['TotalCharges'].astype(int)
df['MonthlyCharges'] = df['MonthlyCharges'].astype(int)

# %%
df.columns
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges',
#        'gender_Male', 'Partner_Yes', 'Dependents_Yes', 'PhoneService_Yes',
#        'PaperlessBilling_Yes', 'Churn_Yes', 'MultipleLines_No phone service',
#        'MultipleLines_Yes', 'InternetService_Fiber optic',
#        'InternetService_No', 'OnlineSecurity_No internet service',
#        'OnlineSecurity_Yes', 'OnlineBackup_No internet service',
#        'OnlineBackup_Yes', 'DeviceProtection_No internet service',
#        'DeviceProtection_Yes', 'TechSupport_No internet service',
#        'TechSupport_Yes', 'StreamingTV_No internet service', 'StreamingTV_Yes',
#        'StreamingMovies_No internet service', 'StreamingMovies_Yes',
#        'Contract_One year', 'Contract_Two year',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
X = df.drop('Churn_Yes', axis = 1)

# %%
y = df['Churn_Yes']

# %%
X_train, X_test, y_train ,y_test = train_test_split(X,y)

# %%
for i in [X_train, y_train, X_test, y_test]:
    print(i.shape)
# Out:
# (5282, 30)
# (5282,)
# (1761, 30)
# (1761,)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
# Out:
# C:\Users\Prem\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
predictions = rf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, predictions)

# %%
confusion = confusion_matrix(y_test, predictions)

# %%
print(accuracy, "is the Accuracy score")
# Out:
# 0.7739920499716071 is the Accuracy score

# %%
print(confusion, "This is the confusion score")
# Out:
# [[1158  153]
#  [ 245  205]] This is the confusion score

# %%
print(precision_score(y_test, predictions), "is the precision score")
# Out:
# 0.5726256983240223 is the precision score

# %%
print(recall_score(y_test, predictions), "is the recall score")
# Out:
# 0.45555555555555555 is the recall score

# %%
print(f1_score(y_test, predictions), "is the f1_score")
# Out:
# 0.5074257425742574 is the f1_score

# %% [markdown]
# # Let's check the hyperparameters

# %%
from sklearn.metrics import roc_curve, auc

# %%
n_estimators = [1, 2, 4, 8, 16, 32, 64, 100, 200]
train_results = []
test_results = []

# %%
for estimator in n_estimators:
   rf = RandomForestClassifier(n_estimators=estimator, n_jobs=-1)
   rf.fit(X_train, y_train)
   train_pred = rf.predict(X_train)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train, train_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   train_results.append(roc_auc)
   y_pred = rf.predict(X_test)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   test_results.append(roc_auc)

# %%
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(n_estimators, train_results, 'b', label='Train AUC')
line2, = plt.plot(n_estimators, test_results, 'r', label='Test AUC')
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('AUC score')
plt.xlabel('n_estimators')
plt.show()

# %% [markdown]
# # Our sweet spot for random-foresrt lies somewhere between 10-20 dtrees
# # Because post that point there is not surge or dip in the AUC

# %%
max_depths = np.linspace(1, 40, 40, endpoint=True)
train_results = []
test_results = []
for max_depth in max_depths:
   rf = RandomForestClassifier(max_depth=max_depth, n_jobs=-1)
   rf.fit(X_train, y_train)
   train_pred = rf.predict(X_train)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train, train_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   train_results.append(roc_auc)
   y_pred = rf.predict(X_test)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   test_results.append(roc_auc)
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(max_depths, train_results, 'b', label='Train AUC')
line2, = plt.plot(max_depths, test_results, 'r', label='Test AUC')
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('AUC score')
plt.xlabel('Tree depth')
plt.show()
# Out:
# C:\Users\Prem\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Prem\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Prem\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Prem\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %% [markdown]
# # Let's say the sweet spot here is 5 - 10 levels

# %%
min_samples_splits = np.linspace(0.1, 1.0, 10, endpoint=True)
train_results = []
test_results = []
for min_samples_split in min_samples_splits:
   rf = RandomForestClassifier(min_samples_split=min_samples_split)
   rf.fit(X_train, y_train)
   train_pred = rf.predict(X_train)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train, train_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   train_results.append(roc_auc)
   y_pred = rf.predict(X_test)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   test_results.append(roc_auc)
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(min_samples_splits, train_results, 'b', label='Train AUC')
line2, = plt.plot(min_samples_splits, test_results, 'r', label='Test AUC')
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('AUC score')
plt.xlabel('min samples split')
plt.show()
# Out:
# C:\Users\Prem\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Prem\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Prem\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Prem\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %% [markdown]
# # This metrics seems to be a player
# # Further more let's say the sweet spot is 0.2 here
# # Which is 20% of total no of samples we have here

# %%
X_train.shape[0]*0.2
# Out:
# 1056.4

# %% [markdown]
# # So we consider 1050 samples at each split and these 1050 samples are choose in a bootstrap basis

# %%
min_samples_leafs = [1,10,100,1000]
train_results = []
test_results = []
for min_samples_leaf in min_samples_leafs:
   rf = RandomForestClassifier(min_samples_leaf=min_samples_leaf)
   rf.fit(X_train, y_train)
   train_pred = rf.predict(X_train)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train, train_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   train_results.append(roc_auc)
   y_pred = rf.predict(X_test)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   test_results.append(roc_auc)
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(min_samples_leafs, train_results, 'b', label='Train AUC')
line2, = plt.plot(min_samples_leafs, test_results, 'r', label='Test AUC')
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('AUC score')
plt.xlabel('min samples leaf')
plt.show()
# Out:
# C:\Users\Prem\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Prem\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Prem\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Prem\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %% [markdown]
# # Increasing this model leads to underfitting
# # The inference here is these is a sweetspot 50-150

# %%
max_features = list(range(1,X_train.shape[1]))
train_results = []
test_results = []
for max_feature in max_features:
   rf = RandomForestClassifier(max_features=max_feature)
   rf.fit(X_train, y_train)
   train_pred = rf.predict(X_train)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train, train_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   train_results.append(roc_auc)
   y_pred = rf.predict(X_test)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   test_results.append(roc_auc)
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(max_features, train_results, 'b', label='Train AUC')
line2, = plt.plot(max_features, test_results, 'r', label='Test AUC')
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('AUC score')
plt.xlabel('max features')
plt.show()
# Out:
# C:\Users\Prem\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Prem\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Prem\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Prem\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %% [markdown]
# # There is an inexplicable overfitting here
# # But let's still we can fixate 12-15 as the spot where we have the best AUC

# %% [markdown]
# ### Now let's try to build a grid search

# %%
from sklearn.model_selection import GridSearchCV

# %%
max_features = [12,13,14,15]
min_samples_leaf = [50,60,70,80,90,100]
min_samples_split = [0.15,0.2,0.25]
max_depth = [5,6,7,8,9,10]
n_estimators =  [20,22,24,26,28,30]
param_grid = {'max_depth': max_depth, 'max_features' : max_features, 'min_samples_leaf':min_samples_leaf,
             'min_samples_split': min_samples_split, 'n_estimators' :n_estimators}
grid_search = GridSearchCV(rf, param_grid, cv=5, n_jobs = -1)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=29,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=10, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
# ...

# %%
grid_search.best_params_
# Out:
# {'max_depth': 8,
#  'max_features': 12,
#  'min_samples_leaf': 50,
#  'min_samples_split': 0.2,
#  'n_estimators': 24}

# %%
grid_search.best_score_
# Out:
# 0.7885270730783794

# %%
rf = RandomForestClassifier(max_depth = 8 ,max_features= 12,min_samples_leaf= 50,min_samples_split= 0.2,n_estimators= 24)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=8, max_features=12, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=50, min_samples_split=0.2,
#                        min_weight_fraction_leaf=0.0, n_estimators=24,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
preds=rf.predict(X_test)

# %%
accuracy_score(preds, y_test)
# Out:
# 0.8040885860306644

# %%
importance = rf.feature_importances_

# %%
Columns = X_train.columns.tolist()

# %%
Importance = pd.DataFrame(importance, index = Columns)

# %%
Importance
# Out:
#                                               0
# SeniorCitizen                          0.000000
# tenure                                 0.321520
# MonthlyCharges                         0.062200
# TotalCharges                           0.098447
# gender_Male                            0.000000
# Partner_Yes                            0.008267
# Dependents_Yes                         0.000000
# PhoneService_Yes                       0.000279
# PaperlessBilling_Yes                   0.000000
# MultipleLines_No phone service         0.000799
# MultipleLines_Yes                      0.000000
# InternetService_Fiber optic            0.234248
# InternetService_No                     0.010912
# OnlineSecurity_No internet service     0.000388
# OnlineSecurity_Yes                     0.000000
# OnlineBackup_No internet service       0.001806
# OnlineBackup_Yes                       0.000000
# DeviceProtection_No internet service   0.000000
# DeviceProtection_Yes                   0.000000
# ...

# %%
Importance.sort_values(by= 0 , ascending = False)
# Out:
#                                               0
# tenure                                 0.321520
# InternetService_Fiber optic            0.234248
# Contract_Two year                      0.137694
# TotalCharges                           0.098447
# MonthlyCharges                         0.062200
# PaymentMethod_Electronic check         0.061471
# Contract_One year                      0.045003
# StreamingMovies_No internet service    0.016179
# InternetService_No                     0.010912
# Partner_Yes                            0.008267
# OnlineBackup_No internet service       0.001806
# MultipleLines_No phone service         0.000799
# StreamingTV_No internet service        0.000787
# OnlineSecurity_No internet service     0.000388
# PhoneService_Yes                       0.000279
# TechSupport_Yes                        0.000000
# StreamingMovies_Yes                    0.000000
# PaymentMethod_Credit card (automatic)  0.000000
# StreamingTV_Yes                        0.000000
# ...

# %%
df.sort_values(by = 'tenure', ascending = True)
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 1340              0       0              56             0            0
# 936               0       0              80             0            0
# 6670              0       0              73             0            0
# 4380              0       0              20             0            0
# 5218              0       0              19             0            1
# ...             ...     ...             ...           ...          ...
# 914               0      72              25          1798            1
# 917               0      72              65          4807            1
# 4574              1      72             105          7629            0
# 3635              0      72              24          1750            0
# 3543              0      72             105          7581            1
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  PaperlessBilling_Yes  \
# ...

# %%
Importance.iloc[:,0]
# Out:
# SeniorCitizen                            0.000000
# tenure                                   0.321520
# MonthlyCharges                           0.062200
# TotalCharges                             0.098447
# gender_Male                              0.000000
# Partner_Yes                              0.008267
# Dependents_Yes                           0.000000
# PhoneService_Yes                         0.000279
# PaperlessBilling_Yes                     0.000000
# MultipleLines_No phone service           0.000799
# MultipleLines_Yes                        0.000000
# InternetService_Fiber optic              0.234248
# InternetService_No                       0.010912
# OnlineSecurity_No internet service       0.000388
# OnlineSecurity_Yes                       0.000000
# OnlineBackup_No internet service         0.001806
# OnlineBackup_Yes                         0.000000
# DeviceProtection_No internet service     0.000000
# DeviceProtection_Yes                     0.000000
# ...
